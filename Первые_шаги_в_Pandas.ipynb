# %%
# импортирование библиотеки
import pandas as pd

# %%
# чтение файла и просмотр загруженных данных
df = pd.read_csv('WHR_2019.csv')
df.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
# пример создания собственного датафрейма вручную
my_df1 = pd.DataFrame({'id': [1, 2, 3],
                      'name': ['Bob', 'Alice', 'Scott'],
                      'age': [21, 15, 30]})

my_df2 = pd.DataFrame([[1,'Bob', 21],
                  [2,'Alice', 15],
                  [3,'Scott', 30]], 
columns=['id','name', 'age'])
display(my_df1)
print('-----------------')
display(my_df2)
# Out:
#    id   name  age
# 0   1    Bob   21
# 1   2  Alice   15
# 2   3  Scott   30
# -----------------
#    id   name  age
# 0   1    Bob   21
# 1   2  Alice   15
# 2   3  Scott   30

# %%
# размеры датафрейма
print(df.shape) # размеры сразу по двум осям
print(df.shape[0]) # кол-во строк
print(df.shape[1]) # кол-во столбцов
# Out:
# (156, 9)
# 156
# 9

# %%
# переименовывание столбцов
df.rename(columns = {'Overall rank':'Место в рейтинге', 'Country or region':'Страна или регион', 'Score':'Баллы', 'GDP per capita':'ВВП на душу населения', 'Social support':'Социальная поддержка', 'Healthy life expectancy':'Ожидаемая продолжительность здоровой жизни', 'Freedom to make life choices': 'Свобода жизненных выборов', 'Generosity':  'Щедрость', 'Perceptions of corruption':'Восприятие коррупции' }, inplace = True)
df.head()
# Out:
#    Место в рейтинге Страна или регион  ...  Щедрость  Восприятие коррупции
# 0                 1           Finland  ...     0.153                 0.393
# 1                 2           Denmark  ...     0.252                 0.410
# 2                 3            Norway  ...     0.271                 0.341
# 3                 4           Iceland  ...     0.354                 0.118
# 4                 5       Netherlands  ...     0.322                 0.298
#
# [5 rows x 9 columns]

# %%
# характеристики датасета
df.describe()
# Out:
#        Место в рейтинге       Баллы  ...    Щедрость  Восприятие коррупции
# count        156.000000  156.000000  ...  156.000000            156.000000
# mean          78.500000    5.407096  ...    0.184846              0.110603
# std           45.177428    1.113120  ...    0.095254              0.094538
# min            1.000000    2.853000  ...    0.000000              0.000000
# 25%           39.750000    4.544500  ...    0.108750              0.047000
# 50%           78.500000    5.379500  ...    0.177500              0.085500
# 75%          117.250000    6.184500  ...    0.248250              0.141250
# max          156.000000    7.769000  ...    0.566000              0.453000
#
# [8 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Место в рейтинге                            156 non-null    int64
#  1   Страна или регион                           156 non-null    object
#  2   Баллы                                       156 non-null    float64
#  3   ВВП на душу населения                       156 non-null    float64
#  4   Социальная поддержка                        156 non-null    float64
#  5   Ожидаемая продолжительность здоровой жизни  156 non-null    float64
#  6   Свобода жизненных выборов                   156 non-null    float64
#  7   Щедрость                                    156 non-null    float64
#  8   Восприятие коррупции                        156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# сохранение отдельных столбцов датафрейма в новой переменной
data_new = df[['Место в рейтинге', 'Ожидаемая продолжительность здоровой жизни']]
data_new.head(5)
# Out:
#    Место в рейтинге  Ожидаемая продолжительность здоровой жизни
# 0                 1                                       0.986
# 1                 2                                       0.996
# 2                 3                                       1.028
# 3                 4                                       1.026
# 4                 5                                       0.999

# %%
# срез по именам столбцов
df.loc [:, 'Место в рейтинге':'Социальная поддержка']
# Out:
#      Место в рейтинге  ... Социальная поддержка
# 0                   1  ...                1.587
# 1                   2  ...                1.573
# 2                   3  ...                1.582
# 3                   4  ...                1.624
# 4                   5  ...                1.522
# ..                ...  ...                  ...
# 151               152  ...                0.711
# 152               153  ...                0.885
# 153               154  ...                0.517
# 154               155  ...                0.000
# 155               156  ...                0.575
#
# [156 rows x 5 columns]

# %%
# срез по строкам и по столбцам
df.iloc[0:100, 0:5]
# Out:
#     Место в рейтинге  ... Социальная поддержка
# 0                  1  ...                1.587
# 1                  2  ...                1.573
# 2                  3  ...                1.582
# 3                  4  ...                1.624
# 4                  5  ...                1.522
# ..               ...  ...                  ...
# 95                96  ...                0.910
# 96                97  ...                1.513
# 97                98  ...                0.868
# 98                99  ...                0.808
# 99               100  ...                1.226
#
# [100 rows x 5 columns]

# %%
# выделение столбца в список
score_list = df['Баллы'].tolist()
# score_list

# %%
# частый пример - преобразование имён столбцов в список
df.columns.tolist()
# Out:
# ['Место в рейтинге',
#  'Страна или регион',
#  'Баллы',
#  'ВВП на душу населения',
#  'Социальная поддержка',
#  'Ожидаемая продолжительность здоровой жизни',
#  'Свобода жизненных выборов',
#  'Щедрость',
#  'Восприятие коррупции']

# %%
# добавление нового столбца в датасет
df['Сумма'] = df['ВВП на душу населения'] + df['Социальная поддержка']
df.head(5)
# Out:
#    Место в рейтинге Страна или регион  ...  Восприятие коррупции  Сумма
# 0                 1           Finland  ...                 0.393  2.927
# 1                 2           Denmark  ...                 0.410  2.956
# 2                 3            Norway  ...                 0.341  3.070
# 3                 4           Iceland  ...                 0.118  3.004
# 4                 5       Netherlands  ...                 0.298  2.918
#
# [5 rows x 10 columns]

# %%
# добавление новой строки в датасет
new_row = {'Место в рейтинге': 100, 'Страна или регион': 'Country', 'Баллы': 100}
df = df.append(new_row, ignore_index=True)
df.tail(5)
# Out:
#      Место в рейтинге         Страна или регион  ...  Восприятие коррупции  Сумма
# 152               153                  Tanzania  ...                 0.147  1.361
# 153               154               Afghanistan  ...                 0.025  0.867
# 154               155  Central African Republic  ...                 0.035  0.026
# 155               156               South Sudan  ...                 0.091  0.881
# 156               100                   Country  ...                   NaN    NaN
#
# [5 rows x 10 columns]

# %%
# добавление строки с суммарными значениями
df = df.append(df.sum(axis=0), ignore_index=True)
df.tail(5)
# Out:
#      Место в рейтинге  ...    Сумма
# 153               154  ...    0.867
# 154               155  ...    0.026
# 155               156  ...    0.881
# 156               100  ...      NaN
# 157             12346  ...  329.778
#
# [5 rows x 10 columns]

# %%
# удаление созданного столбца
df = df.drop(['Сумма'], axis=1)
df.head(5)
# Out:
#    Место в рейтинге Страна или регион  ...  Щедрость  Восприятие коррупции
# 0                 1           Finland  ...     0.153                 0.393
# 1                 2           Denmark  ...     0.252                 0.410
# 2                 3            Norway  ...     0.271                 0.341
# 3                 4           Iceland  ...     0.354                 0.118
# 4                 5       Netherlands  ...     0.322                 0.298
#
# [5 rows x 9 columns]

# %%
# удаление последней строки
df = df.drop(df.shape[0]-1, axis=0)
df.tail(5)
# Out:
#      Место в рейтинге         Страна или регион  ...  Щедрость  Восприятие коррупции
# 152               153                  Tanzania  ...     0.276                 0.147
# 153               154               Afghanistan  ...     0.158                 0.025
# 154               155  Central African Republic  ...     0.235                 0.035
# 155               156               South Sudan  ...     0.202                 0.091
# 156               100                   Country  ...       NaN                   NaN
#
# [5 rows x 9 columns]

# %%
# копирование датафрейма
df_copied = df.copy()
df_copied.head(5)
# Out:
#    Место в рейтинге Страна или регион  ...  Щедрость  Восприятие коррупции
# 0                 1           Finland  ...     0.153                 0.393
# 1                 2           Denmark  ...     0.252                 0.410
# 2                 3            Norway  ...     0.271                 0.341
# 3                 4           Iceland  ...     0.354                 0.118
# 4                 5       Netherlands  ...     0.322                 0.298
#
# [5 rows x 9 columns]

# %%
# вывод уникальных значений и их количества при помощи функции длины датасета
df['Страна или регион'].unique() # вывод самих значений
len(df['Страна или регион'].unique()) # их кол-ва
# Out:
# 157

# %%
# подсчёт количества значений (по странам)
df['Страна или регион'].value_counts()
# видим, что в датасете все страны уникальны :)
# Out:
# Mauritania    1
# Zambia        1
# Benin         1
# Indonesia     1
# Chile         1
#              ..
# Kenya         1
# Serbia        1
# Ghana         1
# Honduras      1
# Gabon         1
# Name: Страна или регион, Length: 157, dtype: int64

# %%
# группировка данных
df['Баллы_new'] = round(df['Баллы'])
df.groupby('Баллы_new').count() # обычный подсчёт кол-ва значений
# Out:
#            Место в рейтинге  Страна или регион  ...  Щедрость  Восприятие коррупции
# Баллы_new                                       ...
# 3.0                       9                  9  ...         9                     9
# 4.0                      26                 26  ...        26                    26
# 5.0                      48                 48  ...        48                    48
# 6.0                      49                 49  ...        49                    49
# 7.0                      21                 21  ...        21                    21
# 8.0                       3                  3  ...         3                     3
# 100.0                     1                  1  ...         0                     0
#
# [7 rows x 9 columns]

# %%
# группировка с подсчётом суммы по группам
df.groupby('Баллы_new').sum()
# Out:
#            Место в рейтинге    Баллы  ...  Щедрость  Восприятие коррупции
# Баллы_new                             ...
# 3.0                    1368   29.444  ...     1.770                 1.116
# 4.0                    3497  108.678  ...     5.253                 2.213
# 5.0                    4680  239.294  ...     8.427                 4.110
# 6.0                    2401  294.443  ...     7.499                 4.028
# 7.0                     294  148.725  ...     5.211                 4.643
# 8.0                       6   22.923  ...     0.676                 1.144
# 100.0                   100  100.000  ...     0.000                 0.000
#
# [7 rows x 8 columns]

# %%
# группировка с подсчётом среднего значения по группам
df.groupby('Баллы_new').mean()
# Out:
#            Место в рейтинге       Баллы  ...  Щедрость  Восприятие коррупции
# Баллы_new                                ...
# 3.0                   152.0    3.271556  ...  0.196667              0.124000
# 4.0                   134.5    4.179923  ...  0.202038              0.085115
# 5.0                    97.5    4.985292  ...  0.175562              0.085625
# 6.0                    49.0    6.009041  ...  0.153041              0.082204
# 7.0                    14.0    7.082143  ...  0.248143              0.221095
# 8.0                     2.0    7.641000  ...  0.225333              0.381333
# 100.0                 100.0  100.000000  ...       NaN                   NaN
#
# [7 rows x 8 columns]

# %%
# группировка с подсчётом медианы по группам
df.groupby('Баллы_new').median()
# Out:
#            Место в рейтинге     Баллы  ...  Щедрость  Восприятие коррупции
# Баллы_new                              ...
# 3.0                   152.0    3.3340  ...     0.217                0.0910
# 4.0                   134.5    4.2490  ...     0.192                0.0850
# 5.0                    97.5    5.0035  ...     0.176                0.0725
# 6.0                    49.0    6.0460  ...     0.142                0.0640
# 7.0                    14.0    7.0900  ...     0.263                0.2260
# 8.0                     2.0    7.6000  ...     0.252                0.3930
# 100.0                 100.0  100.0000  ...       NaN                   NaN
#
# [7 rows x 8 columns]

# %%
# группировка с агрегацией сразу по нескольким функциям
df_agg = df.groupby('Баллы_new').agg({
    'Баллы_new': 'count',
    'Баллы_new': 'sum',
    'Баллы_new': 'mean',
    'Баллы_new': 'median'
})
df_agg
# Out:
#            Баллы_new
# Баллы_new
# 3.0              3.0
# 4.0              4.0
# 5.0              5.0
# 6.0              6.0
# 7.0              7.0
# 8.0              8.0
# 100.0          100.0

# %%
# подготовка и создание сводной таблицы
df['ВВП_new'] = round(df['ВВП на душу населения'])
pd.pivot_table(df,
               index=['Баллы_new'],
               columns=['ВВП_new'],
               values='Социальная поддержка',
               aggfunc='mean')
# Out:
# ВВП_new         0.0       1.0     2.0
# Баллы_new
# 3.0        0.630143  0.761500     NaN
# 4.0        0.900667  1.083818     NaN
# 5.0        0.910111  1.172256     NaN
# 6.0             NaN  1.374478  1.3650
# 7.0             NaN  1.497263  1.3945
# 8.0             NaN  1.580667     NaN

# %%
# сортировка данных (по умолчанию - по возрастанию)
df.sort_values(by='ВВП на душу населения').head()
# Out:
#      Место в рейтинге         Страна или регион  ...  Баллы_new  ВВП_new
# 111               112                   Somalia  ...        5.0      0.0
# 154               155  Central African Republic  ...        3.0      0.0
# 144               145                   Burundi  ...        4.0      0.0
# 140               141                   Liberia  ...        4.0      0.0
# 126               127          Congo (Kinshasa)  ...        4.0      0.0
#
# [5 rows x 11 columns]

# %%
# сортировка данных (по убыванию, добавляем параметр ascending)
df.sort_values(by='ВВП на душу населения', ascending=False).head()
# Out:
#     Место в рейтинге     Страна или регион  ...  Баллы_new  ВВП_new
# 28                29                 Qatar  ...        6.0      2.0
# 13                14            Luxembourg  ...        7.0      2.0
# 33                34             Singapore  ...        6.0      2.0
# 20                21  United Arab Emirates  ...        7.0      2.0
# 50                51                Kuwait  ...        6.0      2.0
#
# [5 rows x 11 columns]

# %%
# примеры фильтрации
df[df['Страна или регион'] == 'Norway']
# Out:
#    Место в рейтинге Страна или регион  ...  Баллы_new  ВВП_new
# 2                 3            Norway  ...        8.0      1.0
#
# [1 rows x 11 columns]

# %%
df[df['Ожидаемая продолжительность здоровой жизни'] > 1]
# Out:
#     Место в рейтинге Страна или регион  ...  Баллы_new  ВВП_new
# 2                  3            Norway  ...        8.0      1.0
# 3                  4           Iceland  ...        7.0      1.0
# 5                  6       Switzerland  ...        7.0      1.0
# 6                  7            Sweden  ...        7.0      1.0
# 7                  8       New Zealand  ...        7.0      1.0
# 8                  9            Canada  ...        7.0      1.0
# 9                 10           Austria  ...        7.0      1.0
# 10                11         Australia  ...        7.0      1.0
# 12                13            Israel  ...        7.0      1.0
# 13                14        Luxembourg  ...        7.0      2.0
# 23                24            France  ...        7.0      1.0
# 29                30             Spain  ...        6.0      1.0
# 33                34         Singapore  ...        6.0      2.0
# 35                36             Italy  ...        6.0      1.0
# ...

# %%
df[df['Страна или регион'].str.startswith('F')]
# Out:
#     Место в рейтинге Страна или регион  ...  Баллы_new  ВВП_new
# 0                  1           Finland  ...        8.0      1.0
# 23                24            France  ...        7.0      1.0
#
# [2 rows x 11 columns]

# %%
df[(df['ВВП на душу населения'] > 1) & (df['Социальная поддержка'] > 1.5)]
# Out:
#     Место в рейтинге Страна или регион  ...  Баллы_new  ВВП_new
# 0                  1           Finland  ...        8.0      1.0
# 1                  2           Denmark  ...        8.0      1.0
# 2                  3            Norway  ...        8.0      1.0
# 3                  4           Iceland  ...        7.0      1.0
# 4                  5       Netherlands  ...        7.0      1.0
# 5                  6       Switzerland  ...        7.0      1.0
# 7                  8       New Zealand  ...        7.0      1.0
# 8                  9            Canada  ...        7.0      1.0
# 10                11         Australia  ...        7.0      1.0
# 14                15    United Kingdom  ...        7.0      1.0
# 15                16           Ireland  ...        7.0      1.0
# 17                18           Belgium  ...        7.0      1.0
# 21                22             Malta  ...        7.0      1.0
# 37                38          Slovakia  ...        6.0      1.0
# ...

# %%
# пример написания собственной функции и применение её через метод apply()
def my_lower(row):
  return row.lower()
df['Страна или регион'].apply(my_lower).head()
# Out:
# 0        finland
# 1        denmark
# 2         norway
# 3        iceland
# 4    netherlands
# Name: Страна или регион, dtype: object

# %%
# удаление дубликатов строк из датасета по заданным столбцам
df_copied = df.copy()
df_copied.drop_duplicates(subset=['ВВП_new', 'Баллы_new'])
# Out:
#      Место в рейтинге Страна или регион  ...  Баллы_new  ВВП_new
# 0                   1           Finland  ...        8.0      1.0
# 3                   4           Iceland  ...        7.0      1.0
# 13                 14        Luxembourg  ...        7.0      2.0
# 24                 25            Taiwan  ...        6.0      1.0
# 28                 29             Qatar  ...        6.0      2.0
# 73                 74        Tajikistan  ...        5.0      0.0
# 74                 75           Croatia  ...        5.0      1.0
# 121               122        Mauritania  ...        4.0      1.0
# 122               123        Mozambique  ...        4.0      0.0
# 147               148          Botswana  ...        3.0      1.0
# 149               150            Malawi  ...        3.0      0.0
# 156               100           Country  ...      100.0      NaN
#
# [12 rows x 11 columns]

# %%
df_copied = df.copy()
df_copied.drop_duplicates(subset=['ВВП_new', 'Баллы_new'], inplace=True)

# %%
# заполним пропуски нулями или удалим все NaN
df_copied.fillna(0)
# df_copied.dropna()
# Out:
#      Место в рейтинге Страна или регион  ...  Баллы_new  ВВП_new
# 0                   1           Finland  ...        8.0      1.0
# 3                   4           Iceland  ...        7.0      1.0
# 13                 14        Luxembourg  ...        7.0      2.0
# 24                 25            Taiwan  ...        6.0      1.0
# 28                 29             Qatar  ...        6.0      2.0
# 73                 74        Tajikistan  ...        5.0      0.0
# 74                 75           Croatia  ...        5.0      1.0
# 121               122        Mauritania  ...        4.0      1.0
# 122               123        Mozambique  ...        4.0      0.0
# 147               148          Botswana  ...        3.0      1.0
# 149               150            Malawi  ...        3.0      0.0
# 156               100           Country  ...      100.0      0.0
#
# [12 rows x 11 columns]

# %%
# обычный график зависимости
df.plot(x = 'Место в рейтинге', y = 'ВВП на душу населения')

# %%
# гистограмма
df.plot.hist(x = 'Место в рейтинге', y = 'ВВП на душу населения')

# %%
# точечный график
df.plot.scatter(y = 'Место в рейтинге', x = 'ВВП на душу населения')

# %%
# сохранение файла
df.to_csv('WHR_2019.csv')
