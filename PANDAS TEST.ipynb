# %%
import pandas as pd

data = pd.Series(["Январь", "Февраль", "Март", "Апрель"],
                 index = ['Первый', "Второй", "Третий", "Четвёртый"])
display(data)
# Out:
# Первый        Январь
# Второй       Февраль
# Третий          Март
# Четвёртый     Апрель
# dtype: object

# %%
print(data.loc["Первый"])
# Out:
# Январь

# %%
print(data.loc[["Первый", "Третий"]])
# Out:
# Первый    Январь
# Третий      Март
# dtype: object

# %%
print(data[["Первый", "Третий"]])
# Out:
# Первый    Январь
# Третий      Март
# dtype: object

# %%
print(data.iloc[[0, 2]])
# Out:
# Первый    Январь
# Третий      Март
# dtype: object

# %%
df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
display(df)
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df = pd.DataFrame([ [1,2,3], [2,3,4] ],
                  columns = ['foo', 'bar', 'baz'], 
                  index = ['foobar', 'foobaz'])
display(df)
# Out:
#         foo  bar  baz
# foobar    1    2    3
# foobaz    2    3    4

# %%
fotball = pd.read_csv("pandas/players.csv")
display(fotball.head())
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
display(fotball.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
football.describe()
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
display(football.describe())
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
df = pd.DataFrame([[i,i+1.2,i+2, 'hi'] for i in range(10)],
                  columns = ['foo', 'bar', 'baz', 'foobar'])
display(df.mean())
# Out:
# C:\Users\i.kubalov\AppData\Local\Temp\ipykernel_5588\3064898786.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   display(df.mean())
# foo    4.5
# bar    5.7
# baz    6.5
# dtype: float64

# %%
df['foo']
df.bar
# Out:
# 0     1.2
# 1     2.2
# 2     3.2
# 3     4.2
# 4     5.2
# 5     6.2
# 6     7.2
# 7     8.2
# 8     9.2
# 9    10.2
# Name: bar, dtype: float64

# %%
df.bar.mean()
# Out:
# 5.7

# %%
import pandas as pd
football = pd.read_csv("pandas/players.csv")
football[football.Age > 43]
# Out:
#        Unnamed: 0           Name  Age        Nationality                Club  \
# 1628         1695       O. Pérez   45             Mexico             Pachuca
# 12422       12651      T. Warner   44  Trinidad & Tobago  Accrington Stanley
# 12873       13102  K. Pilkington   44            England    Cambridge United
#
#          Value  Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 1628   1300000  8000       GK        19         14  ...         23         62
# 12422        0  1000       GK        19         13  ...         17         46
# 12873        0  1000       GK        11         12  ...         22         56
#
#        Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 1628        23              12             11        70          64
# 12422       19              15             14        48          56
# 12873       15              15             13        45          48
#
#        GKKicking  GKPositioning  GKReflexes
# ...

# %%
football[football.Age > football.Age.mean()].head()
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
football[(football.Age < football.Age.mean())|
        (football.Club == 'FC Barcelona')].head()
# Out:
#     Unnamed: 0           Name  Age Nationality               Club      Value  \
# 0            0       L. Messi   31   Argentina       FC Barcelona  110500000
# 7            7      L. Suárez   31     Uruguay       FC Barcelona   80000000
# 15          15      P. Dybala   24   Argentina           Juventus   89000000
# 16          16        H. Kane   24     England  Tottenham Hotspur   83500000
# 18          18  M. ter Stegen   26     Germany       FC Barcelona   58000000
#
#       Wage Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 0   565000       RF        84         95  ...         75         96       33
# 7   455000       RS        77         93  ...         85         85       62
# 15  205000       LF        82         84  ...         86         84       23
# 16  205000       ST        75         94  ...         90         89       56
# 18  240000       GK        15         14  ...         25         69       25
#
# ...

# %%
football[(football.Age < football.Age.mean())&
        (football.Club == 'FC Barcelona')].Wage.mean()
# Out:
# 77454.54545454546

# %%
football[(football.Wage < football.Wage.mean())].SprintSpeed.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 football[(football.Wage < football.Wage.mean())].SprintSpeed.mean()
#
# NameError: name 'football' is not defined

# %%
football[(football.Wage.max())]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 565000
#
# ...

# %%
football[(football.Age < football.Age.mean())&
        (football.Club == 'FC Barcelona')].Wage.mean()
# Out:
# 77454.54545454546

# %%
football[(football.HeadingAccuracy > 50)].Age
# Out:
# 0        31
# 1        33
# 2        26
# 4        27
# 5        27
#          ..
# 12769    18
# 12777    21
# 12788    19
# 12818    19
# 12893    19
# Name: Age, Length: 7519, dtype: int64

# %%
football[(football.Composure > 0.9) & (
      football.Reactions  > 0.9)]
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
# ...

# %%
import pandas as pd
df  = pd.read_csv("pandas/players.csv")
small_df = df[df.columns[1:8]].head(25)

# %%
display(small_df)
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
s = small_df['Nationality'].value_counts()
display(s)
# Out:
# Spain        4
# Argentina    3
# Belgium      3
# Uruguay      3
# Germany      3
# France       2
# Portugal     1
# Brazil       1
# Croatia      1
# Slovenia     1
# Poland       1
# England      1
# Italy        1
# Name: Nationality, dtype: int64

# %%
s.index
# Out:
# Index(['Spain', 'Argentina', 'Belgium', 'Uruguay', 'Germany', 'France',
#        'Portugal', 'Brazil', 'Croatia', 'Slovenia', 'Poland', 'England',
#        'Italy'],
#       dtype='object')

# %%
s.index[0]
# Out:
# 'Spain'

# %%
s[s > 1]
# Out:
# Spain        4
# Argentina    3
# Belgium      3
# Uruguay      3
# Germany      3
# France       2
# Name: Nationality, dtype: int64

# %%
s = small_df['Nationality'].value_counts(normalize=True)
display(s)
# Out:
# Spain        0.16
# Argentina    0.12
# Belgium      0.12
# Uruguay      0.12
# Germany      0.12
# France       0.08
# Portugal     0.04
# Brazil       0.04
# Croatia      0.04
# Slovenia     0.04
# Poland       0.04
# England      0.04
# Italy        0.04
# Name: Nationality, dtype: float64

# %%
s = small_df['Age'].value_counts()
display(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [145], line 1
# ----> 1 s = small_df['Age'].value_counts()
#       2 display(s)
#
# TypeError: 'method' object is not subscriptable

# %%
s = small_df['Wage'].value_counts(bins=4)
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
#         Name  Age Nationality          Club      Value    Wage Position
# 0   L. Messi   31   Argentina  FC Barcelona  110500000  565000       RF
# 7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000       RS

# %%
import pandas as pd
football  = pd.read_csv("pandas/players.csv")
a =football[(football.Age == football.Age.max())].Reactions.mean()
b = football[(football.Age == football.Age.min())].Reactions.mean()
c = a - b 
display(round(a - b,2))
#Определите, на сколько средняя реакция (Reactions) самых взрослых игроков (т.е. игроков, чей возраст (Age) равен максимальному) больше средней реакции самых молодых игроков. Ответ округлите до сотых.
# Out:
# 22.64

# %%
import pandas as pd
football  = pd.read_csv("pandas/players.csv")
football.info
#Из какой страны (Nationality) происходит больше всего игроков, чья стоимость (Value) превышает среднее значение?
# Out:
# <bound method DataFrame.info of        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
# ...

# %%
import pandas as pd
football  = pd.read_csv("pandas/players.csv")
a = football[(football.GKReflexes==football.GKReflexes.max())].Wage.mean()
b = football[(football.GKHandling==football.GKHandling.max())].Wage.mean()
display(round(a/b,2))
#Определите, во сколько раз средняя зарплата (Wage) голкипера (Position, GK) с максимальным значением показателя " Рефлексы" (GKReflexes) выше средней зарплаты голкипера с максимальным значением показателя "Владение мячом" (GKHandling). Ответ округлите до сотых.
# Out:
# 2.77

# %%
import pandas as pd
football  = pd.read_csv("pandas/players.csv")
a = football[(football.Aggression==football.Aggression.max())].ShotPower.mean()
b = football[(football.Aggression==football.Aggression.min())].ShotPower.mean()
display(round(a / b,2))

#Определите, во сколько раз средняя сила удара (ShotPower) самых агрессивных игроков (игроков с максимальным значением показателя "Агрессивность" (Aggression)) выше средней силы удара игроков с минимальной агрессией.Ответ округлите до сотых.
# Out:
# 2.08

# %%
import pandas as pd
football  = pd.read_csv("pandas/players.csv")
football[(football.Nationality == "Brazil")].Penalties.sum()

#Сколько пенальти (Penalties) забили бразильские (Nationality, Brazil) футболисты за период, данные о котором представлены в датасете?
# Out:
# 22789

# %%
import pandas as pd
football  = pd.read_csv("pandas/players.csv")
football[(football.Name == football.Nationality)].Value.mean()
# Out:
# nan

# %%
#ГРУППИРОВКА#ГРУППИРОВКА#ГРУППИРОВКА#ГРУППИРОВКА#ГРУППИРОВКА

# %%
import pandas as pd
df  = pd.read_csv("pandas/players.csv")

# %%
small_df = df[df.columns[1:8]].head(25)
small_df
#КОЛОНКА С 1 ПО 7,25СТРОЕЧЕК
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
import pandas as pd
df  = pd.read_csv("pandas/players.csv")
small_df = df[df.columns[1:8]].head(25)
s = small_df['Nationality'].value_counts()
s
#СЧЕТЧИК ЗНАЧЕНИЙ
# Out:
# Spain        4
# Argentina    3
# Belgium      3
# Uruguay      3
# Germany      3
# France       2
# Portugal     1
# Brazil       1
# Croatia      1
# Slovenia     1
# Poland       1
# England      1
# Italy        1
# Name: Nationality, dtype: int64

# %%
a = small_df['Name'].value_counts()
a.loc[a > 1]
# Out:
# Series([], Name: Name, dtype: int64)

# %%
s = small_df['Position'].value_counts(normalize=True)
s.loc[s < 0.1]
# Out:
# RCM    0.08
# LF     0.08
# LCM    0.08
# RF     0.04
# LW     0.04
# RS     0.04
# RCB    0.04
# CB     0.04
# LDM    0.04
# CAM    0.04
# CDM    0.04
# LS     0.04
# LCB    0.04
# Name: Position, dtype: float64

# %%
s = small_df['Age'].value_counts()
display(s)
# Out:
# 27    5
# 32    5
# 31    3
# 26    3
# 33    2
# 29    2
# 24    2
# 25    1
# 28    1
# 30    1
# Name: Age, dtype: int64

# %%
s = small_df['Wage'].value_counts()
display(s)
# Out:
# 205000    3
# 355000    2
# 240000    2
# 125000    1
# 300000    1
# 130000    1
# 200000    1
# 315000    1
# 145000    1
# 225000    1
# 285000    1
# 565000    1
# 405000    1
# 94000     1
# 380000    1
# 455000    1
# 420000    1
# 340000    1
# 260000    1
# 290000    1
# 215000    1
# Name: Wage, dtype: int64

# %%
s = small_df['Wage'].value_counts(bins=4)
display(s)
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64
#         Name  Age Nationality          Club      Value    Wage Position
# 0   L. Messi   31   Argentina  FC Barcelona  110500000  565000       RF
# 7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000       RS

# %%
import pandas as pd
df  = pd.read_csv("pandas/players.csv")
small_df = df[df.columns[0:7]].head(25)

s = small_df['Wage'].value_counts(bins=4)

display(s)

s.index

s.index[3]

s.index[3].left

s.index[3].right
#small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
small_df['Wage'] > s.index[3].left

# %%
#УНИКАЛЬНЫЕ ЗНАЧЕНИЯ 
import pandas as pd
df  = pd.read_csv("pandas/players.csv")
small_df = df[df.columns[0:7]].head(25)
print(small_df['Nationality'].unique())#  Уникальное значение списка
print(small_df['Nationality'].nunique())# Уникальное значение число
# Out:
# ['Argentina' 'Portugal' 'Brazil' 'Spain' 'Belgium' 'Croatia' 'Uruguay'
#  'Slovenia' 'Poland' 'Germany' 'France' 'England' 'Italy']
# 13

# %%
import pandas as pd
df  = pd.read_csv("pandas/players.csv")
small_df = df[df.columns[0:7]].head(25)
s = small_df['Nationality'].value_counts()
s_df = s.reset_index()# Преобразование в 
s_df.columns = ['Nationality','Players Count']
display(s_df)
# Out:
#    Nationality  Players Count
# 0        Spain              4
# 1    Argentina              3
# 2      Belgium              3
# 3      Uruguay              3
# 4      Germany              3
# 5       France              2
# 6     Portugal              1
# 7       Brazil              1
# 8      Croatia              1
# 9     Slovenia              1
# 10      Poland              1
# 11     England              1
# 12       Italy              1

# %%
import pandas as pd
df  = pd.read_csv("pandas/players.csv")
small_df = df[df.columns[0:7]].head(25)
s = small_df['Wage'].value_counts(bins=4)
s.loc[(small_df.Nationality['Spain'])]
#small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [24], line 5
#       3 small_df = df[df.columns[0:7]].head(25)
#       4 s = small_df['Wage'].value_counts(bins=4)
# ----> 5 s.loc[(small_df.Nationality['Spain'])]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
# ...

# %%
import pandas as pd
df  = pd.read_csv("pandas/players.csv")
df.groupby(['Club']).groups # Группиорвка по значению
# Out:
# {' SSV Jahn Regensburg': [1642, 2284, 2374, 2401, 2575, 2583, 2850, 2868, 3418, 3908, 3989, 4154, 5151, 5177, 5525, 5885, 6070, 6679, 7173, 7477, 8905, 9061, 10825, 12482], '1. FC Heidenheim 1846': [1060, 1805, 1978, 2050, 2066, 2926, 3584, 3605, 4312, 4457, 4783, 6818, 7160, 7166, 7460, 9475, 10052, 10565, 11217, 12236], '1. FC Kaiserslautern': [2931, 3590, 4270, 4413, 4475, 4483, 4709, 4779, 5079, 5325, 5403, 5855, 5917, 7295, 8784, 9496, 9964, 10019, 10122, 10671, 11500, 11970, 12222], '1. FC Köln': [166, 379, 899, 1399, 3415, 6904, 7052, 8892, 12171, 12376], '1. FC Magdeburg': [1967, 2069, 2152, 2569, 2886, 3030, 3300, 3332, 4436, 4913, 5002, 5033, 5493, 5768, 6329, 7046, 7595, 8387, 9626, 11125, 11400], '1. FC Nürnberg': [724, 1208, 1254, 1920, 4775, 5265, 5556, 5985, 8590, 8632, 9217, 9858, 10480], '1. FC Union Berlin': [1422, 1493, 2530, 2876, 3635, 3844, 4683, 4826, 11038, 11296, 12340], '1. FSV Mainz 05': [545, 670, 765, 1201, 1342, 6218, 6868, 8792, 10293, 10561, 10566], 'A
# ...

# %%
df.groupby(['Club']).groups # Группировка по значениям групп
# Out:
# {' SSV Jahn Regensburg': [1642, 2284, 2374, 2401, 2575, 2583, 2850, 2868, 3418, 3908, 3989, 4154, 5151, 5177, 5525, 5885, 6070, 6679, 7173, 7477, 8905, 9061, 10825, 12482], '1. FC Heidenheim 1846': [1060, 1805, 1978, 2050, 2066, 2926, 3584, 3605, 4312, 4457, 4783, 6818, 7160, 7166, 7460, 9475, 10052, 10565, 11217, 12236], '1. FC Kaiserslautern': [2931, 3590, 4270, 4413, 4475, 4483, 4709, 4779, 5079, 5325, 5403, 5855, 5917, 7295, 8784, 9496, 9964, 10019, 10122, 10671, 11500, 11970, 12222], '1. FC Köln': [166, 379, 899, 1399, 3415, 6904, 7052, 8892, 12171, 12376], '1. FC Magdeburg': [1967, 2069, 2152, 2569, 2886, 3030, 3300, 3332, 4436, 4913, 5002, 5033, 5493, 5768, 6329, 7046, 7595, 8387, 9626, 11125, 11400], '1. FC Nürnberg': [724, 1208, 1254, 1920, 4775, 5265, 5556, 5985, 8590, 8632, 9217, 9858, 10480], '1. FC Union Berlin': [1422, 1493, 2530, 2876, 3635, 3844, 4683, 4826, 11038, 11296, 12340], '1. FSV Mainz 05': [545, 670, 765, 1201, 1342, 6218, 6868, 8792, 10293, 10561, 10566], 'A
# ...

# %%
grouped_df = df.groupby(['Club']).sum() # группировка значений и их сумма
display(grouped_df.head(25))
# Out:
#                        Unnamed: 0  Age      Value    Wage  Crossing  \
# Club
#  SSV Jahn Regensburg       129124  609   15195000   90000      1104
# 1. FC Heidenheim 1846      117834  473   18290000   76000       961
# 1. FC Kaiserslautern       167351  544   11195000   33000      1106
# 1. FC Köln                  54865  225   46810000   92000       444
# 1. FC Magdeburg            116731  515   57525000   84000       948
# 1. FC Nürnberg              75281  291   28540000   93000       646
# 1. FC Union Berlin          61586  271    9485000   94000       572
# 1. FSV Mainz 05             59103  238   41755000  125000       574
# AC Ajaccio                 118215  507   24000000   42000       958
# AC Horsens                 210346  625    8650000   55000      1141
# AD Alcorcón                 89198  506   36875000   70000      1000
# ADO Den Haag               114251  450   14680000   67000       972
# AEK Athens                  43824  266   39550000   11000       521
# ...

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum()
display(grouped_df.head(30)) # Выборка
# Out:
# Club
#  SSV Jahn Regensburg      90000
# 1. FC Heidenheim 1846     76000
# 1. FC Kaiserslautern      33000
# 1. FC Köln                92000
# 1. FC Magdeburg           84000
# 1. FC Nürnberg            93000
# 1. FC Union Berlin        94000
# 1. FSV Mainz 05          125000
# AC Ajaccio                42000
# AC Horsens                55000
# AD Alcorcón               70000
# ADO Den Haag              67000
# AEK Athens                11000
# AFC Wimbledon             51000
# AIK                       46000
# AJ Auxerre                34000
# AS Béziers                31000
# AS Monaco                770000
# AS Nancy Lorraine         53000
# AS Saint-Étienne         213000
# AZ Alkmaar                60000
# Aalborg BK                59000
# Aarhus GF                 72000
# Aberdeen                  49000
# Accrington Stanley        67000
# Adelaide United           33000
# Ajax                     158000
# Akhisar Belediyespor      94000
# Al Ahli                  232000
# ...

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False) # Группировка значений с самой большой суммой
print(grouped_df.head(20))
# Out:
# Club
# Real Madrid            4138000
# FC Barcelona           3967000
# Manchester City        3097000
# Manchester United      2357000
# Juventus               2335000
# Liverpool              2163000
# FC Bayern München      2051000
# Chelsea                2035000
# Tottenham Hotspur      1841000
# Arsenal                1795000
# Paris Saint-Germain    1620000
# West Ham United        1221000
# Atlético Madrid        1143000
# Milan                  1134000
# Napoli                 1042000
# Everton                1014000
# Inter                   949000
# Roma                    854000
# Borussia Dortmund       789000
# AS Monaco               770000
# Name: Wage, dtype: int64

# %%
grouped_df = df.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)
print(grouped_df.head(20)> 5000000) # Группировка игроков по позиции , вывод по деньгам
# Out:
# Position
# ST      True
# GK      True
# CB      True
# CM      True
# LB      True
# CAM     True
# LM      True
# RM      True
# RB      True
# CDM    False
# RCB    False
# LCB    False
# RW     False
# RCM    False
# LCM    False
# LW     False
# LS     False
# RDM    False
# RS     False
# LDM    False
# Name: Wage, dtype: bool

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()  #Для подсчета среднего мы будем использовать агрегирующую функцию mean
# Out:
#                      Wage        Age  ShotPower
# Nationality
# Afghanistan   1250.000000  22.500000  53.750000
# Albania       5931.034483  23.689655  54.551724
# Algeria      15810.810811  27.027027  56.567568
# Andorra       1000.000000  28.000000  58.000000
# Angola        7100.000000  24.700000  63.700000
# ...                   ...        ...        ...
# Uzbekistan    9000.000000  29.500000  71.500000
# Venezuela     6611.111111  23.638889  57.222222
# Wales         9529.411765  24.754902  48.558824
# Zambia        2833.333333  21.833333  66.833333
# Zimbabwe      5000.000000  26.555556  62.888889
#
# [156 rows x 3 columns]

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10) #Далее отсортируем по убыванию усредненной зарплаты
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333
# Belgium             20024.390244  24.030488  56.390244
# Ecuador             18333.333333  24.619048  60.666667
# Uruguay             17590.361446  26.771084  56.192771
# Brazil              17371.158392  27.898345  58.203310
# Algeria             15810.810811  27.027027  56.567568

# %%
df.loc[df['Nationality'] == 'Dominican Republic'][['Name','Club','Wage','Age','ShotPower']]
# Out:
#             Name         Club    Wage  Age  ShotPower
# 291      Mariano  Real Madrid  140000   24         85
# 6279  L. Quezada   Córdoba CF    2000   22         66

# %%
df.groupby(['Position'])[['Wage','Value']].mean().sort_values(['Value'],ascending=False).head(10) #Далее отсортируем по убыванию усредненной зарплаты
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06

# %%
df.loc[df['Position'] == 'LF'][['Wage','Value']].mean() # Какова средняя зарплата футболистов на данной позиции?
# Out:
# Wage        75125.0
# Value    27362500.0
# dtype: float64

# %%
import pandas as pd
df  = pd.read_csv("pandas/players.csv")
df.groupby(['Nationality'])[['Club','Name']].nunique()
# Out:
#              Club  Name
# Nationality
# Afghanistan     4     4
# Albania        26    29
# Algeria        33    37
# Andorra         1     1
# Angola          9    10
# ...           ...   ...
# Uzbekistan      2     2
# Venezuela      34    36
# Wales          56   101
# Zambia          5     6
# Zimbabwe        8     9
#
# [156 rows x 2 columns]

# %%
a = df.groupby(['Club'])[['Wage']].mean()
b = df.groupby(['Club'])[['Wage','Name']].median()
b
# Out:
#                          Wage
# Club
#  SSV Jahn Regensburg   3500.0
# 1. FC Heidenheim 1846  3000.0
# 1. FC Kaiserslautern   1000.0
# 1. FC Köln             4000.0
# 1. FC Magdeburg        4000.0
# ...                       ...
# Zagłębie Sosnowiec     1000.0
# Çaykur Rizespor        4500.0
# Örebro SK              1000.0
# Östersunds FK          1000.0
# Śląsk Wrocław          2000.0
#
# [650 rows x 1 columns]

# %%
#df.loc[df['Position'] == 'LF'][['Wage','Value']].mean() 

a =df.groupby(['Club'])[['Wage', 'Name']].agg(['mean','median']).nunique()

a.loc([Wage == [agg(['mean'])
# Out:
#   Cell In [69], line 5
#     a.loc([Wage == [agg(['mean'])
#                                  ^
# SyntaxError: incomplete input

# %%
a=df.groupby(['Club'])[['Wage']].sum()

a.loc['Chelsea']
# Out:
# Wage    2035000
# Name: Chelsea, dtype: int64

# %%
a=df.groupby(['Nationality'])[['Wage','Age']].max()
a.loc[(df.Age<= 20)]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In [74], line 2
#       1 a=df.groupby(['Nationality'])[['Wage','Age']].max()
# ----> 2 a.loc[(df.Age<= 20)]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1185, in _LocIndexer._getitem_axis(self, key, axis)
#    1183     return self._get_slice_axis(key, axis=axis)
#    1184 elif com.is_bool_indexer(key):
# -> 1185     return self._getbool_axis(key, axis=axis)
#    1186 elif is_list_like_indexer(key):
#    1187
#    1188     # an iterable multi-selection
# ...

# %% [markdown]
# ##  СВОДНЫЕ ТАБЛИЦЫ

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True,
fill_value=0)
display(pivot)
# Out:
#                            Wage                                         \
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                565000   205000            206000           0
# Belgium                  110000        0            230000      240000
# Bosnia Herzegovina            0   180000                 0           0
# Brazil                   465000   335000             91000      570000
# Chile                    205000        0            215000           0
# Costa Rica                    0        0                 0      195000
# Croatia                  260000   160000                 0      420000
# Dominican Republic            0        0                 0      140000
# Ecuador                       0        0            120000           0
# England                       0        0            478000           0
# France                   495000   145000            375000      459000
# ...

# %%
df  = pd.read_csv("pandas/players.csv")
df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max',fill_value=0)

df2.loc['Manchester City']['GK']
#Сводная таблица, показывающая максимальные зарплаты игроков на разных позициях, играющих за разные клубы, была создана с помощью кода:
#df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')
#С помощью какого кода можно получить из этой таблицы информацию о максимальной зарплате вратаря (GK), играющего за футбольный клуб "Manchester City"?
# Out:
# 125000

# %%
#С помощью сводной таблицы и функции loc посчитайте, сколько получают ("Wage") русские футболисты ("Russia"), играющие за ФК "AS Monaco".
pivot = df.loc[df['Club'].isin(['AS Monaco'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='max',
margins=True,
fill_value=0)
pivot
#df2.loc['AS Monaco']['GK']
# Out:
#                  Wage
# Club        AS Monaco     All
# Nationality
# Belgium         47000   47000
# Brazil          55000   55000
# Colombia       115000  115000
# Croatia         70000   70000
# France          61000   61000
# Italy           48000   48000
# Montenegro      79000   79000
# Morocco         39000   39000
# Poland          86000   86000
# Portugal        65000   65000
# Russia          61000   61000
# Senegal         10000   10000
# All            115000  115000

# %% [markdown]
# # Создайте сводную таблицу, содержащую сведения о средней скорости футболистов (SprintSpeed), занимающих разные позиции (Position) в разных футбольных клубах (Club).Основываясь на данных таблицы, отметьте три позиции, представители которых обладают самой высокой скоростью.

# %%
pdf = df.pivot_table(columns = 'Club', index = 'Position', values = 'SprintSpeed', aggfunc = 'mean', fill_value = 0)
pdf
# Out:
# Club       SSV Jahn Regensburg  1. FC Heidenheim 1846  1. FC Kaiserslautern  \
# Position
# CAM                   0.000000              68.000000              0.000000
# CB                   46.600000              61.333333             59.000000
# CDM                  82.000000               0.000000             65.666667
# CF                    0.000000               0.000000              0.000000
# CM                   61.000000              68.000000              0.000000
# GK                   33.000000              41.000000             42.666667
# LAM                   0.000000               0.000000              0.000000
# LB                   76.000000              60.000000             68.000000
# LCB                   0.000000              55.000000             45.000000
# LCM                   0.000000               0.000000              0.000000
# LDM                  55.000000               0.000000              0.000000
# ...
